# %% [markdown]
# ## Howard and Anahy's Friday Lab E11
# ## 9-24-2021

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/Users/howardyan/Desktop/Course Notes/Engin 11/Raspberry Pi/weather_and_air.csv")

# %%
df
# Out:
#             Time  PM_1  PM_2_5  PM_10  Temperature   Humidity     Pressure
# 0   1.631743e+09  7168     256    768    25.176367  46.998735  1001.649839
# 1   1.631743e+09  7168     256    768    25.191797  46.969297  1001.619595
# 2   1.631743e+09  7168     256    768    25.196875  46.779120  1001.612849
# 3   1.631743e+09  7168     256    512    25.212109  46.666181  1001.594227
# 4   1.631743e+09  7168     256    512    25.212109  46.624605  1001.636041
# 5   1.631743e+09  7168     256    512    25.232617  46.594922  1001.654845
# 6   1.631743e+09  7168     256    512    25.227539  46.696193  1001.649785
# 7   1.631743e+09  7168     256    512    25.237695  46.690189  1001.637797
# 8   1.631743e+09  7168     256    512    25.247852  46.827091  1001.636151
# 9   1.631743e+09  7168     256    512    25.253125  46.892567  1001.639563
# 10  1.631743e+09  7168     256    512    25.273438  47.005737  1001.642865
# ...

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Time'],df['Temperature'])
plt.xlabel('Time')
plt.ylabel('Temperature (Celsius)')
plt.title('Temperature over Time',size=20);

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Time'],df['Humidity']);
plt.xlabel('Time',size=14)
plt.ylabel('Humidity (Celsius)',size=14);
plt.title('Humidity over Time',size=20);

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Time'],df['Pressure']);
plt.xlabel('Time',size=14)
plt.ylabel('Pressure',size=14);
plt.title('Pressure over Time',size=20);
